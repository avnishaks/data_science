# %%
print("Welcome to world of Quant Computing")
# Out:
# Welcome to world of Quant Computing

# %%
print("Solving complex problem is always fun part")
# Out:
# Solving complex problem is always fun part

# %% [markdown]
# # Python Tutorial ( Recap of Python concept )

# %% [markdown]
# Python is general purpose object oriented programming language
# - its amazing
# - its wonderful

# %% [markdown]
# # Variable , Data Type and TypeCasting

# %%
a=5

# %%
b=10

# %%
a+b
# Out:
# 15

# %%
name="avnish"

# %%
last_name="kumar"

# %%
name+last_name
# Out:
# 'avnishkumar'

# %%
print("hello world")
# Out:
# hello world

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
"""
Random varibale 
"""
print(type(last_name))
# Out:
# <class 'str'>

# %%
x="26262"

# %%
y="90878"

# %%
int(x)+int(y) #typecasting
# Out:
# 117140
