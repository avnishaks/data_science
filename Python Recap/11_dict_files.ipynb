# %%
"""
A dictionary in Python is an unordered, mutable, and key-value pair collection.
It allows efficient data retrieval and modification.
Dictionaries in Python are ordered as of Python 3.7

"""
# Out:
# '\nA dictionary in Python is an unordered, mutable, and key-value pair collection.\nIt allows efficient data retrieval and modification.\nDictionaries in Python are ordered as of Python 3.7\n\n'

# %%
dict ={}

# %%
type(dict)
# Out:
# dict

# %%
student = {
    "name": "Avnish",
    "age" :25 ,
    "grade":"A"
}

# %%
student
# Out:
# {'name': 'Avnish', 'age': 25, 'grade': 'A'}

# %%
student["age"]
# Out:
# 25

# %%
student["grade"]
# Out:
# 'A'

# %%
student ["age"] =90

# %%
student.get("age")
# Out:
# 90

# %%
student
# Out:
# {'name': 'Avnish', 'age': 90, 'grade': 'A'}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
student.values()
# Out:
# dict_values(['Avnish', 90, 'A'])

# %%
student.items()
# Out:
# dict_items([('name', 'Avnish'), ('age', 90), ('grade', 'A')])

# %%
student.update({"name":"Random"})

# %%
student
# Out:
# {'name': 'Random', 'age': 90, 'grade': 'A'}

# %%
student.update({"core":"Data Science"})

# %%
student
# Out:
# {'name': 'Random', 'age': 90, 'grade': 'A', 'core': 'Data Science'}

# %%
f=open("intro.txt","r")

# %%
f.read()
# Out:
# 'Welcome to world of Quant Programming '

# %%
f.close()

# %%
s="New learning series from E2E basic to pro level begin here"

# %%
f=open("random.txt","w")

# %%
f.write(s)
# Out:
# 58

# %%
f=open("random.txt","r")

# %%
f.read()
# Out:
# 'New learning series from E2E basic to pro level begin here'
