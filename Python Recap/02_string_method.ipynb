# %%
name="avnishaaa"

# %%
name.upper()
# Out:
# 'AVNISHAAA'

# %%
name.capitalize()
# Out:
# 'Avnishaaa'

# %%
name.count("a")
# Out:
# 4

# %%
name.endswith("h")
# Out:
# False

# %%
name.endswith("a")
# Out:
# True

# %%
len(name)
# Out:
# 9

# %%
name[0:5]
# Out:
# 'avnis'

# %%
name[1:-3]
# Out:
# 'vnish'
