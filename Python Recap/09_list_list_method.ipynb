# %%
list= [10,70,9,8,9]

# %%
list
# Out:
# [10, 70, 9, 8, 9]

# %%
list[-1]=0

# %%
list
# Out:
# [10, 70, 9, 8, 0]

# %%
list[1:4]
# Out:
# [70, 9, 8]

# %%
list[1:-1]
# Out:
# [70, 9, 8]

# %%
list[1:-3]
# Out:
# [70]

# %%
"""
list is mutable when we modify any value the original list will be modified !

"""
# Out:
# '\nlist is mutable when we modify any value the original list will be modified !\n\n'

# %%
list.append(800)

# %%
list
# Out:
# [10, 70, 9, 8, 0, 800]

# %%
list2=[9,18]

# %%
list2.extend(list)

# %%
list
# Out:
# [10, 70, 9, 8, 0, 800]

# %%
list2
# Out:
# [9, 18, 10, 70, 9, 8, 0, 800]

# %%
list2.pop(-1)
# Out:
# 800

# %%
list2
# Out:
# [9, 18, 10, 70, 9, 8, 0]

# %%
list2.count(9)
# Out:
# 2

# %%
list.count(9)
# Out:
# 1

# %%
list.sort()

# %%
list
# Out:
# [0, 8, 9, 10, 70, 800]

# %%
list.sort(reverse=True)

# %%
list
# Out:
# [800, 70, 10, 9, 8, 0]

# %%
new_list=[2,38,900,272,90.8,6,78]

# %%
sorted(new_list)
# Out:
# [2, 6, 38, 78, 90.8, 272, 900]

# %%
sorted(new_list).reverse
# Out:
# <function list.reverse()>
