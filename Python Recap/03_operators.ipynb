# %%
a=True
b=False

# %%
not(a)
# Out:
# False

# %%
not(b)
# Out:
# True

# %%
a or b
# Out:
# True

# %%
a & b
# Out:
# False

# %%
a ^ b
# Out:
# True

# %%
not(a) ^ b
# Out:
# False

# %%
not(b) ^ a
# Out:
# False

# %%
list =[1,2,3,4,5]

# %%
z=5

# %%
z in list
# Out:
# True

# %%
z+2 in list
# Out:
# False

# %%
z is a
# Out:
# False

# %%
z is not a
# Out:
# True

# %%
a is b
# Out:
# False

# %%
a is a
# Out:
# True

# %%
b is a
# Out:
# False

# %%
d=5

# %%
z is d
# Out:
# True

# %%
f= True

# %%
a is f
# Out:
# True

# %%
f is b
# Out:
# False

# %%
h= False

# %%
h is b
# Out:
# True

# %%
not(h) is a
# Out:
# True

# %%
not(f) is b
# Out:
# True

# %%
a is not(b)
# Out:
# True

# %%
not(a) is b
# Out:
# True

# %%
a is not b
# Out:
# True

# %%
f is not h
# Out:
# True

# %%
h is not b
# Out:
# False

# %%
f is not(a)
# Out:
# False

# %%
not(a) is not f
# Out:
# True
