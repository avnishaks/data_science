# %% [markdown]
# Operator precedence in python work in formate for the PEMDAS
# -

# %%
"""
PEMDAS Concept belong to operator precedence in python :- 

1. Parentheses { highest precendence operator inside parenthesis are evaluated first }
2. Exponents { Power Calculation } -> { evaluated from right to left )
3. Multiplication , Division , Floor Division , Modulus { evaluate from left to right }
4. Addition and Substraction { evaluate from left to right } 

"""
# Out:
# '\nPEMDAS Concept belong to operator precedence in python :- \n\n1. Parentheses { highest precendence operator inside parenthesis are evaluated first }\n2. Exponents { Power Calculation } -> { evaluated from right to left )\n3. Multiplication , Division , Floor Division , Modulus { evaluate from left to right }\n4. Addition and Substraction { evaluate from left to right } \n\n'
